# %%
# %run train_models.py
# %run data_cleaning.py

# %%
data_osteo = pd.read_csv('osteo_discretized.csv') 
data_osteo.shape
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (61022, 208)

# %%
#convert float to string, preparing for OHE
var = ['Calcium_Closest_Osteo_decile', 'Calcium_Avg_Prior_decile','Calcium_Avg_Ever_decile',
    'Sodium_Avg_Prior_decile','Sodium_Avg_Ever_decile','Sodium_Worst_Prior_decile','Sodium_Worst_Ever_decile',  
       'Sodium_Closest_Osteo_decile',
    'Calcium_Closest_Osteo_cat', 'Calcium_Avg_Prior_cat','Calcium_Avg_Ever_cat',
   'Sodium_Avg_Prior_cat','Sodium_Avg_Ever_cat','Sodium_Worst_Prior_cat','Sodium_Worst_Ever_cat']
for i in var: 
    print(i)
    convert_to_str(data_osteo,i)
    print(' ')
# Out:
# Calcium_Closest_Osteo_decile
# before convert:  float64
# after convert:  object
#
# Calcium_Avg_Prior_decile
# before convert:  float64
# after convert:  object
#
# Calcium_Avg_Ever_decile
# before convert:  float64
# after convert:  object
#
# Sodium_Avg_Prior_decile
# before convert:  float64
# after convert:  object
#
# Sodium_Avg_Ever_decile
# before convert:  float64
# after convert:  object
#
# Sodium_Worst_Prior_decile
# before convert:  float64
# after convert:  object
#
# Sodium_Worst_Ever_decile
# before convert:  float64
# after convert:  object
#
# Sodium_Closest_Osteo_decile
# before convert:  int64
# after convert:  object
#
# Calcium_Closest_Osteo_cat
# before convert:  int64
# after convert:  object
#
# Calcium_Avg_Prior_cat
# before convert:  int64
# after convert:  object
#
# Calcium_Avg_Ever_cat
# before convert:  int64
# after convert:  object
#
# Sodium_Avg_Prior_cat
# before convert:  int64
# after convert:  object
#
# Sodium_Avg_Ever_cat
# before convert:  int64
# after convert:  object
#
# Sodium_Worst_Prior_cat
# before convert:  int64
# after convert:  object
#
# Sodium_Worst_Ever_cat
# before convert:  int64
# after convert:  object

# %%
# extract needed columns
osteo_extract_filter = data_osteo.filter(['Strata','sex','Race_Cat_combine', 'Age_combine','osteo_predict', 'BMI_Avg_imputed', 
     'Alcohol_Prior', 'Tobacco_Prior','Drug_antipsych_prior', 'Drug_Estrogens_prior', 'Drug_Glucocorticoids_prior',
    'Drug_Nsaids_prior', 'Drug_Opiates_prior', 'Drug_Thiazide_prior','Drug_Loop_Diuretic_Prior',
      'Drug_Pp_inhibitors_prior',  'Drug_Progesterone_prior',   'Drug_Seizure_prior',  'Drug_Ssris_prior',
 'Drug_Tc_antidepress_prior',  'HeartDisease_Prior',  'Liver_Prior', 'PulmDisease_Prior',  'CNS_Disease_Prior',                                               
 'Malignancy_Prior','Hyponatremia_Prior','Chronic_Hyponatremia', 'Recent_Hyponatremia',
                                          
    'Calcium_Closest_Osteo_decile','Calcium_Avg_Prior_decile','Calcium_Avg_Ever_decile','Sodium_Closest_Osteo_decile',
    
    'Sodium_Avg_Prior_decile','Sodium_Avg_Ever_decile','Sodium_Worst_Prior_decile','Sodium_Worst_Ever_decile',
    'Calcium_Closest_Osteo_cat', 'Calcium_Avg_Prior_cat','Calcium_Avg_Ever_cat','Sodium_Avg_Prior_cat',
   'Sodium_Avg_Ever_cat','Sodium_Worst_Prior_cat','Sodium_Worst_Ever_cat']) 

osteo_extract_filter.shape
# Out:
# (61022, 43)

# %%
osteo_extract_filter.dtypes
# Out:
# Strata                            int64
# sex                              object
# Race_Cat_combine                 object
# Age_combine                      object
# osteo_predict                     int64
# BMI_Avg_imputed                 float64
# Alcohol_Prior                     int64
# Tobacco_Prior                     int64
# Drug_antipsych_prior              int64
# Drug_Estrogens_prior              int64
# Drug_Glucocorticoids_prior        int64
# Drug_Nsaids_prior                 int64
# Drug_Opiates_prior                int64
# Drug_Thiazide_prior               int64
# Drug_Loop_Diuretic_Prior          int64
# Drug_Pp_inhibitors_prior          int64
# Drug_Progesterone_prior           int64
# Drug_Seizure_prior                int64
# Drug_Ssris_prior                  int64
# Drug_Tc_antidepress_prior         int64
# HeartDisease_Prior                int64
# Liver_Prior                       int64
# PulmDisease_Prior                 int64
# CNS_Disease_Prior                 int64
# Malignancy_Prior                  int64
# Hyponatremia_Prior                int64
# Chronic_Hyponatremia              int64
# Recent_Hyponatremia               int64
# Calcium_Closest_Osteo_decile     object
# Calcium_Avg_Prior_decile         object
# Calcium_Avg_Ever_decile          object
# Sodium_Closest_Osteo_decile      object
# Sodium_Avg_Prior_decile          object
# Sodium_Avg_Ever_decile           object
# Sodium_Worst_Prior_decile        object
# Sodium_Worst_Ever_decile         object
# Calcium_Closest_Osteo_cat        object
# Calcium_Avg_Prior_cat            object
# Calcium_Avg_Ever_cat             object
# Sodium_Avg_Prior_cat             object
# Sodium_Avg_Ever_cat              object
# Sodium_Worst_Prior_cat           object
# Sodium_Worst_Ever_cat            object
# dtype: object

# %%
# data_OHE = OHE(osteo_extract_filter)
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)

# %%
TRAIN_TOGETHER(osteo_extract_filter, 'LR', 'sex')
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.71      0.79      0.75     30511
#           1       0.76      0.68      0.72     30511
#
# avg / total       0.73      0.73      0.73     61022
#
#
# [[23981  6530]
#  [ 9873 20638]]
#
# ROC_AUC of LR   0.8189677812670446
#
# subgroups: F    53852
# M     7170
# Name: sex, dtype: int64
# sex_F              precision    recall  f1-score   support
#
#           0       0.71      0.79      0.74     26926
#           1       0.76      0.67      0.71     26926
#
# avg / total       0.73      0.73      0.73     53852
#
# [[21165  5761]
#  [ 8767 18159]]
# ROC_AUC of sex_F 0.8182812785746266
# -----
# sex_M              precision    recall  f1-score   support
#
#           0       0.72      0.79      0.75      3585
#           1       0.76      0.69      0.73      3585
#
# avg / total       0.74      0.74      0.74      7170
#
# [[2816  769]
#  [1106 2479]]
# ROC_AUC of sex_M 0.8242306682305981
# -----

# %%
TRAIN_TOGETHER(osteo_extract_filter, 'LR', 'Race_Cat_combine')
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.71      0.79      0.75     30511
#           1       0.76      0.68      0.72     30511
#
# avg / total       0.73      0.73      0.73     61022
#
#
# [[23981  6530]
#  [ 9873 20638]]
#
# ROC_AUC of LR   0.8189677812670446
#
# subgroups: white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
# Race_Cat_combine_black              precision    recall  f1-score   support
#
#           0       0.72      0.78      0.75      8628
#           1       0.76      0.69      0.73      8628
#
# avg / total       0.74      0.74      0.74     17256
#
# [[6772 1856]
#  [2648 5980]]
# ROC_AUC of Race_Cat_combine_black 0.8306531128825752
# ----
# Race_Cat_combine_others              precision    recall  f1-score   support
#
#           0       0.63      0.70      0.66      3664
#           1       0.66      0.58      0.62      3664
#
# avg / total       0.64      0.64      0.64      7328
#
# [[2567 1097]
#  [1540 2124]]
# ROC_AUC of Race_Cat_combine_others 0.7064805567208863
# ----
# Race_Cat_combine_white              precision    recall  f1-score   support
#
#           0       0.72      0.80      0.76     18219
#           1       0.78      0.69      0.73     18219
#
# avg / total       0.75      0.75      0.74     36438
#
# [[14642  3577]
#  [ 5685 12534]]
# ROC_AUC of Race_Cat_combine_white 0.8317228602159225
# ----

# %%
TRAIN_TOGETHER(osteo_extract_filter, 'LR', 'Age_combine')
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.71      0.79      0.75     30511
#           1       0.76      0.68      0.72     30511
#
# avg / total       0.73      0.73      0.73     61022
#
#
# [[23981  6530]
#  [ 9873 20638]]
#
# ROC_AUC of LR   0.8189677812670446
#
# subgroups: from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
# Age_combine_from_30_to_50              precision    recall  f1-score   support
#
#           0       0.69      0.75      0.72      3632
#           1       0.73      0.67      0.70      3632
#
# avg / total       0.71      0.71      0.71      7264
#
# [[2732  900]
#  [1212 2420]]
# ROC_AUC of Age_combine_from_30_to_50 0.7924785830551728
# ------
# Age_combine_from_50_to_70              precision    recall  f1-score   support
#
#           0       0.69      0.76      0.73     12954
#           1       0.74      0.66      0.70     12954
#
# avg / total       0.71      0.71      0.71     25908
#
# [[9877 3077]
#  [4399 8555]]
# ROC_AUC of Age_combine_from_50_to_70 0.8005528952234375
# ------
# Age_combine_from_70_to_80              precision    recall  f1-score   support
#
#           0       0.73      0.81      0.77      7356
#           1       0.79      0.70      0.74      7356
#
# avg / total       0.76      0.76      0.76     14712
#
# [[5976 1380]
#  [2206 5150]]
# ROC_AUC of Age_combine_from_70_to_80 0.8431496477889341
# ------
# Age_combine_less_than_30              precision    recall  f1-score   support
#
#           0       0.70      0.76      0.73       492
#           1       0.74      0.67      0.70       492
#
# avg / total       0.72      0.71      0.71       984
#
# [[375 117]
#  [164 328]]
# ROC_AUC of Age_combine_less_than_30 0.7881469363474122
# ------
# Age_combine_more_than_80              precision    recall  f1-score   support
#
#           0       0.73      0.83      0.77      6077
#           1       0.80      0.69      0.74      6077
#
# avg / total       0.76      0.76      0.76     12154
#
# [[5021 1056]
#  [1892 4185]]
# ROC_AUC of Age_combine_more_than_80 0.8398785981960595
# ------

# %%
TRAIN_TOGETHER(osteo_extract_filter, 'RF', 'sex')
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76     30511
#           1       0.77      0.70      0.74     30511
#
# avg / total       0.75      0.75      0.75     61022
#
#
# [[24225  6286]
#  [ 9025 21486]]
#
# ROC_AUC of RF   0.8369783501775335
#
# subgroups: F    53852
# M     7170
# Name: sex, dtype: int64
# sex_F              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76     26926
#           1       0.77      0.71      0.74     26926
#
# avg / total       0.75      0.75      0.75     53852
#
# [[21333  5593]
#  [ 7927 18999]]
# ROC_AUC of sex_F 0.8369571765431658
# -----
# sex_M              precision    recall  f1-score   support
#
#           0       0.72      0.81      0.76      3585
#           1       0.78      0.69      0.74      3585
#
# avg / total       0.75      0.75      0.75      7170
#
# [[2892  693]
#  [1098 2487]]
# ROC_AUC of sex_M 0.8378016646923002
# -----

# %%
TRAIN_TOGETHER(osteo_extract_filter, 'RF', 'Race_Cat_combine')
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76     30511
#           1       0.77      0.70      0.74     30511
#
# avg / total       0.75      0.75      0.75     61022
#
#
# [[24225  6286]
#  [ 9025 21486]]
#
# ROC_AUC of RF   0.8369783501775335
#
# subgroups: white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
# Race_Cat_combine_black              precision    recall  f1-score   support
#
#           0       0.75      0.78      0.77      8628
#           1       0.77      0.74      0.75      8628
#
# avg / total       0.76      0.76      0.76     17256
#
# [[6768 1860]
#  [2280 6348]]
# ROC_AUC of Race_Cat_combine_black 0.8479354315143911
# ----
# Race_Cat_combine_others              precision    recall  f1-score   support
#
#           0       0.67      0.73      0.70      3664
#           1       0.70      0.63      0.67      3664
#
# avg / total       0.68      0.68      0.68      7328
#
# [[2674  990]
#  [1341 2323]]
# ROC_AUC of Race_Cat_combine_others 0.7568272782150417
# ----
# Race_Cat_combine_white              precision    recall  f1-score   support
#
#           0       0.73      0.81      0.77     18219
#           1       0.79      0.70      0.74     18219
#
# avg / total       0.76      0.76      0.76     36438
#
# [[14783  3436]
#  [ 5404 12815]]
# ROC_AUC of Race_Cat_combine_white 0.8457196578909735
# ----

# %%
TRAIN_TOGETHER(osteo_extract_filter, 'RF', 'Age_combine')
# Out:
# OHE shape:  (61022, 137)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=137)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76     30511
#           1       0.77      0.70      0.74     30511
#
# avg / total       0.75      0.75      0.75     61022
#
#
# [[24225  6286]
#  [ 9025 21486]]
#
# ROC_AUC of RF   0.8369783501775335
#
# subgroups: from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
# Age_combine_from_30_to_50              precision    recall  f1-score   support
#
#           0       0.71      0.75      0.73      3632
#           1       0.74      0.70      0.72      3632
#
# avg / total       0.72      0.72      0.72      7264
#
# [[2732  900]
#  [1107 2525]]
# ROC_AUC of Age_combine_from_30_to_50 0.8104768294916455
# ------
# Age_combine_from_50_to_70              precision    recall  f1-score   support
#
#           0       0.72      0.76      0.74     12954
#           1       0.75      0.71      0.73     12954
#
# avg / total       0.73      0.73      0.73     25908
#
# [[9845 3109]
#  [3805 9149]]
# ROC_AUC of Age_combine_from_50_to_70 0.8221182295882469
# ------
# Age_combine_from_70_to_80              precision    recall  f1-score   support
#
#           0       0.74      0.82      0.78      7356
#           1       0.80      0.72      0.76      7356
#
# avg / total       0.77      0.77      0.77     14712
#
# [[6057 1299]
#  [2085 5271]]
# ROC_AUC of Age_combine_from_70_to_80 0.8559213831428942
# ------
# Age_combine_less_than_30              precision    recall  f1-score   support
#
#           0       0.72      0.83      0.77       492
#           1       0.80      0.67      0.73       492
#
# avg / total       0.76      0.75      0.75       984
#
# [[409  83]
#  [161 331]]
# ROC_AUC of Age_combine_less_than_30 0.8365618183620861
# ------
# Age_combine_more_than_80              precision    recall  f1-score   support
#
#           0       0.74      0.85      0.79      6077
#           1       0.82      0.69      0.75      6077
#
# avg / total       0.78      0.77      0.77     12154
#
# [[5182  895]
#  [1867 4210]]
# ROC_AUC of Age_combine_more_than_80 0.8543135027419088
# ------

# %% [markdown]
# ### Train separate

# %%
TRAIN_SEPARATELY(osteo_extract_filter, 'sex', 'LR')
# Out:
# F    53852
# M     7170
# Name: sex, dtype: int64
#
# extracting:  F of column:  sex
# new data shape (53852, 42)
#
# OHE shape:  (53852, 135)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=135)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.71      0.79      0.74     26926
#           1       0.76      0.68      0.71     26926
#
# avg / total       0.73      0.73      0.73     53852
#
#
# [[21174  5752]
#  [ 8745 18181]]
#
# ROC_AUC of LR   0.8185026094748589
#
#  ------------------
# F    53852
# M     7170
# Name: sex, dtype: int64
#
# extracting:  M of column:  sex
# new data shape (7170, 42)
#
# OHE shape:  (7170, 135)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=135)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.78      0.75      3585
#           1       0.76      0.71      0.73      3585
#
# avg / total       0.75      0.74      0.74      7170
#
#
# [[2805  780]
#  [1050 2535]]
#
# ROC_AUC of LR   0.8317021371785819
#
#  ------------------

# %%
TRAIN_SEPARATELY(osteo_extract_filter, 'Age_combine', 'LR')
# Out:
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  from_50_to_70 of column:  Age_combine
# new data shape (25908, 42)
#
# OHE shape:  (25908, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.70      0.74      0.72     12954
#           1       0.73      0.68      0.70     12954
#
# avg / total       0.71      0.71      0.71     25908
#
#
# [[9646 3308]
#  [4187 8767]]
#
# ROC_AUC of LR   0.8004059935455512
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  from_70_to_80 of column:  Age_combine
# new data shape (14712, 42)
#
# OHE shape:  (14712, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.81      0.77      7356
#           1       0.79      0.71      0.74      7356
#
# avg / total       0.76      0.76      0.76     14712
#
#
# [[5940 1416]
#  [2170 5186]]
#
# ROC_AUC of LR   0.8427882407661207
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  more_than_80 of column:  Age_combine
# new data shape (12154, 42)
#
# OHE shape:  (12154, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.85      0.79      6077
#           1       0.82      0.68      0.75      6077
#
# avg / total       0.78      0.77      0.77     12154
#
#
# [[5189  888]
#  [1923 4154]]
#
# ROC_AUC of LR   0.8465522638833125
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  from_30_to_50 of column:  Age_combine
# new data shape (7264, 42)
#
# OHE shape:  (7264, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.70      0.74      0.72      3632
#           1       0.73      0.69      0.71      3632
#
# avg / total       0.72      0.71      0.71      7264
#
#
# [[2689  943]
#  [1131 2501]]
#
# ROC_AUC of LR   0.7950882330823419
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  less_than_30 of column:  Age_combine
# new data shape (984, 42)
#
# OHE shape:  (984, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.72      0.78      0.75       492
#           1       0.76      0.70      0.73       492
#
# avg / total       0.74      0.74      0.74       984
#
#
# [[383 109]
#  [149 343]]
#
# ROC_AUC of LR   0.8004990415757816
#
#  ------------------

# %%
TRAIN_SEPARATELY(osteo_extract_filter, 'Race_Cat_combine', 'LR')
# Out:
# white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
#
# extracting:  white of column:  Race_Cat_combine
# new data shape (36438, 42)
#
# OHE shape:  (36438, 134)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=134)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.72      0.80      0.76     18219
#           1       0.78      0.69      0.73     18219
#
# avg / total       0.75      0.75      0.75     36438
#
#
# [[14582  3637]
#  [ 5622 12597]]
#
# ROC_AUC of LR   0.8317455907778643
#
#  ------------------
# white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
#
# extracting:  black of column:  Race_Cat_combine
# new data shape (17256, 42)
#
# OHE shape:  (17256, 134)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=134)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76      8628
#           1       0.77      0.71      0.74      8628
#
# avg / total       0.75      0.75      0.75     17256
#
#
# [[6783 1845]
#  [2537 6091]]
#
# ROC_AUC of LR   0.8369312702290674
#
#  ------------------
# white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
#
# extracting:  others of column:  Race_Cat_combine
# new data shape (7328, 42)
#
# OHE shape:  (7328, 134)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=134)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.62      0.73      0.67      3664
#           1       0.68      0.56      0.61      3664
#
# avg / total       0.65      0.64      0.64      7328
#
#
# [[2684  980]
#  [1626 2038]]
#
# ROC_AUC of LR   0.7136526793205697
#
#  ------------------

# %%
#RF

# %%
TRAIN_SEPARATELY(osteo_extract_filter, 'sex', 'RF')
# Out:
# F    53852
# M     7170
# Name: sex, dtype: int64
#
# extracting:  F of column:  sex
# new data shape (53852, 42)
#
# OHE shape:  (53852, 135)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=135)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76     26926
#           1       0.77      0.70      0.74     26926
#
# avg / total       0.75      0.75      0.75     53852
#
#
# [[21379  5547]
#  [ 8021 18905]]
#
# ROC_AUC of RF   0.836688986945048
#
#  ------------------
# F    53852
# M     7170
# Name: sex, dtype: int64
#
# extracting:  M of column:  sex
# new data shape (7170, 42)
#
# OHE shape:  (7170, 135)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=135)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.79      0.76      3585
#           1       0.77      0.70      0.74      3585
#
# avg / total       0.75      0.75      0.75      7170
#
#
# [[2844  741]
#  [1069 2516]]
#
# ROC_AUC of RF   0.8320748352911655
#
#  ------------------

# %%
TRAIN_SEPARATELY(osteo_extract_filter, 'Age_combine', 'RF')
# Out:
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  from_50_to_70 of column:  Age_combine
# new data shape (25908, 42)
#
# OHE shape:  (25908, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.72      0.76      0.74     12954
#           1       0.74      0.70      0.72     12954
#
# avg / total       0.73      0.73      0.73     25908
#
#
# [[9824 3130]
#  [3889 9065]]
#
# ROC_AUC of RF   0.8188040476426974
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  from_70_to_80 of column:  Age_combine
# new data shape (14712, 42)
#
# OHE shape:  (14712, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.82      0.77      7356
#           1       0.80      0.70      0.74      7356
#
# avg / total       0.77      0.76      0.76     14712
#
#
# [[6056 1300]
#  [2218 5138]]
#
# ROC_AUC of RF   0.8463604616281694
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  more_than_80 of column:  Age_combine
# new data shape (12154, 42)
#
# OHE shape:  (12154, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.85      0.79      6077
#           1       0.82      0.69      0.75      6077
#
# avg / total       0.78      0.77      0.77     12154
#
#
# [[5165  912]
#  [1900 4177]]
#
# ROC_AUC of RF   0.8483389448162764
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  from_30_to_50 of column:  Age_combine
# new data shape (7264, 42)
#
# OHE shape:  (7264, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.70      0.72      0.71      3632
#           1       0.71      0.70      0.71      3632
#
# avg / total       0.71      0.71      0.71      7264
#
#
# [[2620 1012]
#  [1100 2532]]
#
# ROC_AUC of RF   0.7948276471137612
#
#  ------------------
# from_50_to_70    25908
# from_70_to_80    14712
# more_than_80     12154
# from_30_to_50     7264
# less_than_30       984
# Name: Age_combine, dtype: int64
#
# extracting:  less_than_30 of column:  Age_combine
# new data shape (984, 42)
#
# OHE shape:  (984, 132)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=132)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.70      0.75      0.72       492
#           1       0.73      0.68      0.70       492
#
# avg / total       0.71      0.71      0.71       984
#
#
# [[368 124]
#  [158 334]]
#
# ROC_AUC of RF   0.8045041807125388
#
#  ------------------

# %%
TRAIN_SEPARATELY(osteo_extract_filter, 'Race_Cat_combine', 'RF')
# Out:
# white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
#
# extracting:  white of column:  Race_Cat_combine
# new data shape (36438, 42)
#
# OHE shape:  (36438, 134)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=134)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.73      0.81      0.77     18219
#           1       0.78      0.70      0.74     18219
#
# avg / total       0.76      0.75      0.75     36438
#
#
# [[14707  3512]
#  [ 5432 12787]]
#
# ROC_AUC of RF   0.8435447136710044
#
#  ------------------
# white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
#
# extracting:  black of column:  Race_Cat_combine
# new data shape (17256, 42)
#
# OHE shape:  (17256, 134)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=134)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.74      0.79      0.76      8628
#           1       0.77      0.72      0.74      8628
#
# avg / total       0.75      0.75      0.75     17256
#
#
# [[6784 1844]
#  [2412 6216]]
#
# ROC_AUC of RF   0.8434121078121304
#
#  ------------------
# white     36438
# black     17256
# others     7328
# Name: Race_Cat_combine, dtype: int64
#
# extracting:  others of column:  Race_Cat_combine
# new data shape (7328, 42)
#
# OHE shape:  (7328, 134)
#
# Cols: Index(['Strata', 'osteo_predict', 'BMI_Avg_imputed', 'Alcohol_Prior',
#        'Tobacco_Prior', 'Drug_antipsych_prior', 'Drug_Estrogens_prior',
#        'Drug_Glucocorticoids_prior', 'Drug_Nsaids_prior', 'Drug_Opiates_prior',
#        ...
#        'Calcium_Avg_Ever_cat_0', 'Calcium_Avg_Ever_cat_1',
#        'Sodium_Avg_Prior_cat_0', 'Sodium_Avg_Prior_cat_1',
#        'Sodium_Avg_Ever_cat_0', 'Sodium_Avg_Ever_cat_1',
#        'Sodium_Worst_Prior_cat_0', 'Sodium_Worst_Prior_cat_1',
#        'Sodium_Worst_Ever_cat_0', 'Sodium_Worst_Ever_cat_1'],
#       dtype='object', length=134)
#
#
# final result of the whole model:
#              precision    recall  f1-score   support
#
#           0       0.67      0.73      0.70      3664
#           1       0.70      0.65      0.67      3664
#
# avg / total       0.69      0.69      0.69      7328
#
#
# [[2660 1004]
#  [1299 2365]]
#
# ROC_AUC of RF   0.7588353757079384
#
#  ------------------
